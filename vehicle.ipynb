# %%
import pandas as pd # Manejo y análisis de estructuras de datos
import numpy as np # Cálculo numérico y el análisis de datos
import seaborn as sns # Creación gráficos estadísticos
import matplotlib.pyplot as plt # Creación de gráficos en dos dimensiones

# librerías de para implementar modelos de ciencia de datos
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import classification_report, confusion_matrix

# %%
# lectura de datos en Python y lo cargamos en la variable Datos vehicle

Datos = pd.read_csv('./vehicle.csv')

# %%
# Realizamos lectura de los Datos para el análisis exploratorio
Datos.head(50)
# Out:
#                                            name  year  selling_price  \
# 0                        Maruti Swift Dzire VDI  2014         450000
# 1                  Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                      Honda City 2017-2020 EXi  2006         158000
# 3                     Hyundai i20 Sportz Diesel  2010         225000
# 4                        Maruti Swift VXI BSIII  2007         130000
# 5                 Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6                  Maruti Wagon R LXI DUO BSIII  2007          96000
# 7                            Maruti 800 DX BSII  2001          45000
# 8                              Toyota Etios VXD  2011         350000
# 9          Ford Figo Diesel Celebration Edition  2013         200000
# 10              Renault Duster 110PS Diesel RxL  2014         500000
# 11                                Maruti Zen LX  2005          92000
# 12                       Maruti Swift Dzire VDi  2009         280000
# ...

# %%
# Descripción de los datos
Datos.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
#Identificación de Datos Faltantes y Atípicos teniendo encuenta que, las personas no podrian soportar una presion arteriol superior a 180

plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['year'])
plt.title('Identificación de Datos Faltantes y Atípicos', fontsize=10 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos')

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['selling_price'])
plt.title('Identificación de Datos Faltantes y Atípicos', fontsize=10 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos')

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['km_driven'])
plt.title('Identificación de Datos Faltantes y Atípicos', fontsize=10 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos')

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['seats'])
plt.title('Identificación de Datos Faltantes y Atípicos', fontsize=10 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos')

# %%
#Revisión de datos faltantes

print("Cantidad de Registros con cero en nombre: ",Datos['name'].isin([0]).sum())
print("Cantidad de Registros con cero en año: ",Datos['year'].isin([0]).sum())
print("Cantidad de Registros con cero en precio de venta: ",Datos['selling_price'].isin([0]).sum())
print("Cantidad de Registros con cero en km conducidos: ",Datos['km_driven'].isin([0]).sum())
print("Cantidad de Registros con cero en combustible: ",Datos['fuel'].isin([0]).sum())
print("Cantidad de Registros con cero en tipo de vendedor: ",Datos['seller_type'].isin([0]).sum())
print("Cantidad de Registros con cero en transmision: ",Datos['transmission'].isin([0]).sum())
print("Cantidad de Registros con cero en dueño: ",Datos['owner'].isin([0]).sum())
print("Cantidad de Registros con cero en kilometraje: ",Datos['mileage'].isin([0]).sum())
print("Cantidad de Registros con cero en motor: ",Datos['engine'].isin([0]).sum())
print("Cantidad de Registros con cero en maximo poder: ",Datos['max_power'].isin([0]).sum())
print("Cantidad de Registros con cero en esfuerzo de torsion: ",Datos['torque'].isin([0]).sum())
print("Cantidad de Registros con cero en asientos: ",Datos['seats'].isin([0]).sum())
# Out:
# Cantidad de Registros con cero en nombre:  0
# Cantidad de Registros con cero en año:  0
# Cantidad de Registros con cero en precio de venta:  0
# Cantidad de Registros con cero en km conducidos:  0
# Cantidad de Registros con cero en combustible:  0
# Cantidad de Registros con cero en tipo de vendedor:  0
# Cantidad de Registros con cero en transmision:  0
# Cantidad de Registros con cero en dueño:  0
# Cantidad de Registros con cero en kilometraje:  0
# Cantidad de Registros con cero en motor:  0
# Cantidad de Registros con cero en maximo poder:  0
# Cantidad de Registros con cero en esfuerzo de torsion:  0
# Cantidad de Registros con cero en asientos:  0

# %%
#Identificación de Datos Atípicos

plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['seats'])
plt.title('Identificación de Datos Atípicos', fontsize=10 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Atípicos')

# %%
#Conteo de Datos Atípicos

nivel_minimo=2
nivel_maximo=8
Total_Atipicos=((Datos['seats']<nivel_minimo)|(Datos['seats']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 100

# %%
# Filtra Datos Atípicos

Datos=Datos[(Datos['seats']<nivel_maximo)&(Datos['seats']>nivel_minimo)]

# %%
# Validar si se removieron los datos atípicos

Total_Atipicos=((Datos['seats']<nivel_minimo)|(Datos['seats']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
#Revisión del tipo de datos y datos faltantes

Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7569 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7569 non-null   object
#  1   year           7569 non-null   int64
#  2   selling_price  7569 non-null   int64
#  3   km_driven      7569 non-null   int64
#  4   fuel           7569 non-null   object
#  5   seller_type    7569 non-null   object
#  6   transmission   7569 non-null   object
#  7   owner          7569 non-null   object
#  8   mileage        7569 non-null   object
#  9   engine         7569 non-null   object
#  10  max_power      7569 non-null   object
#  11  torque         7569 non-null   object
#  12  seats          7569 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 827.9+ KB

# %%
# Caracteristica de interes-predecir el precio de un automovil-precio de venta

Datos['selling_price'].value_counts()
# Out:
# selling_price
# 300000    213
# 350000    193
# 600000    193
# 550000    187
# 450000    182
#          ...
# 94500       1
# 408000      1
# 654000      1
# 486000      1
# 746000      1
# Name: count, Length: 652, dtype: int64

# %%
Datos[['selling_price']].head(40)
# Out:
#     selling_price
# 0          450000
# 1          370000
# 2          158000
# 3          225000
# 4          130000
# 5          440000
# 6           96000
# 7           45000
# 8          350000
# 9          200000
# 10         500000
# 11          92000
# 12         280000
# 14         180000
# 15         400000
# 16         778000
# 17         500000
# 18         150000
# 19         680000
# 20         174000
# 21         950000
# 22         525000
# 23         600000
# 24         500000
# 25         575000
# 26         275000
# 27         300000
# 28         220000
# 30         670000
# 32         150000
# 33         730000
# 34         650000
# 35         330000
# 36         366000
# 37        1149000
# 38         150000
# 39         425000
# 40         150000
# 41        2100000
# 42         925000

# %%
# Porcentaje de datos para entrenamiento (train) = 75% , y para prueba (test) = 25%

# Se crean variables X y Y para almacenar la información del entrenamiento

X=Datos.drop('selling_price', axis=1)

y=Datos['selling_price']

# %%
print("X=",X.shape,"\ny=", y.shape)
# Out:
# X= (7569, 12)
# y= (7569,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
print (X_train)
# Out:
#                                   name  year  km_driven    fuel  \
# 1706            Mahindra XUV500 W6 2WD  2014      80000  Diesel
# 5520  Volkswagen Polo 1.5 TDI Highline  2016      66000  Diesel
# 7706                     Honda Jazz VX  2016      56494  Petrol
# 6520          Maruti Wagon R VXI BS IV  2016      80000  Petrol
# 6246                  Renault KWID RXT  2016      15000  Petrol
# ...                                ...   ...        ...     ...
# 5299        Tata Tiago 1.2 Revotron XT  2016      30000  Petrol
# 3528              Maruti Swift AMT ZXI  2018      69779  Petrol
# 1777                   Maruti Ritz VDi  2014      90000  Diesel
# 2824          Maruti Vitara Brezza ZDi  2018      50000  Diesel
# 2957  Hyundai Grand i10 1.2 Kappa Asta  2018      25000  Petrol
#
#            seller_type transmission         owner     mileage   engine  \
# 1706        Individual       Manual  Second Owner   15.1 kmpl  2179 CC
# ...

# %%
print (y_train)
# Out:
# 1706    750000
# 5520    540000
# 7706    550000
# 6520    330000
# 6246    350000
#          ...
# 5299    350000
# 3528    600000
# 1777    325000
# 2824    875000
# 2957    580000
# Name: selling_price, Length: 5676, dtype: int64

# %%
print("Cantidad de Registros Mahindra XUV500 W6 2WD: ",Datos['name'].isin(['Mahindra XUV500 W6 2WD']).sum())
# Out:
# Cantidad de Registros Mahindra XUV500 W6 2WD:  28

# %%
Datos['name']=Datos['name'].replace(['Mahindra XUV500 W6 2WD'],Datos['name'].max())

# %%
print("Cantidad de Registros Mahindra XUV500 W6 2WD: ",Datos['name'].isin(['Mahindra XUV500 W6 2WD']).sum())
# Out:
# Cantidad de Registros Mahindra XUV500 W6 2WD:  0

# %%
X_train.shape
# Out:
# (5676, 12)

# %%
X_test.shape
# Out:
# (1893, 12)

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
modelo_regresion = LinearRegression() # liblinear es una libreria para resolver problemas lineales de clasificación y regresión
modelo_regresion.fit (X_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10688\1373911231.py in ?()
#       1 modelo_regresion = LinearRegression() # liblinear es una libreria para resolver problemas lineales de clasificación y regresión
# ----> 2 modelo_regresion.fit (X_train , y_train)
#
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     644         n_jobs_ = self.n_jobs
#     645
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#     651
#
# C:\Anaconda\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     580                 if "estimator" not in check_y_params:
# ...
